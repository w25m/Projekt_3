# %% [markdown]
# # Projekt 3
# ## Autorzy:
# 1. Wojciech Milewski 198153
# 2. Józef Mróz 197803

# %% [markdown]
# ## Kod Python

# %%
import scikit_build_example as mmm
mmm.generateSignal()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 import scikit_build_example as mmm
# ----> 2 mmm.generateSignal()
#
# AttributeError: module 'scikit_build_example' has no attribute 'generateSignal'

# %% [markdown]
# # Funkcja generateSignal() prosi uzytkownika o podanie nastepujacych wartosci:
# - typ funckji (sin, cos, rec, saw)
# - czestotliwosc sygnalu
# - czas trwania (w [s])
# - czy sygnal ma przejsc trasformate DFT (dft, brak)
# - czy sygnal ma byc progowany (tak,nie) w przypadku podania "tak" program pyta o wartosc progu

# %% [markdown]
# ## Generowanie sinusa,cosinusa,prostokątnego i piłokształtnego

# %% [markdown]
# ## Sinus
# -Podaj typ funckji (sin, cos, rec, saw): sin
#
# -Podaj czestotlwosc:5
#
# -Podaj czas sygnalu (w [s]):3
#
# -Podaj rodzaj transformaty (dft, brak): brak
#
# -Czy chcesz progowac sygnal (tak,nie): nie

# %% [markdown]
# ![sinus.png](attachment:e84f0080-506a-4dbc-8154-a1fab83957e6.png)

# %% [markdown]
# ## Cosinus
# -Podaj typ funckji (sin, cos, rec, saw): cos
#
# -Podaj czestotlwosc:5
#
# -Podaj czas sygnalu (w [s]):3
#
# -Podaj rodzaj transformaty (dft, brak): brak
#
# -Czy chcesz progowac sygnal (tak,nie): nie

# %% [markdown]
# ![cosinus.png](attachment:60351a9d-9784-4045-9bee-6f682d35bb39.png)

# %% [markdown]
# ## Prostokatny
# -Podaj typ funckji (sin, cos, rec, saw): rec
#
# -Podaj czestotlwosc:4
#
# -Podaj czas sygnalu (w [s]):5
#
# -Podaj rodzaj transformaty (dft, brak): brak
#
# -Czy chcesz progowac sygnal (tak,nie): nie

# %% [markdown]
# ![rec.png](attachment:69edfe31-079c-4352-9e95-aecd7874e5af.png)

# %% [markdown]
# ## Piloksztaltny
# -Podaj typ funckji (sin, cos, rec, saw): saw
#
# -Podaj czestotlwosc:5
#
# -Podaj czas sygnalu (w [s]):3
#
# -Podaj rodzaj transformaty (dft, brak): brak
#
# -Czy chcesz progowac sygnal (tak,nie): nie

# %% [markdown]
# ![saw.png](attachment:044e0c7d-dc00-4ab8-8873-5b33d30021df.png)

# %% [markdown]
# # Transformata DFT

# %% [markdown]
# ## Przykład 1:
# -Podaj typ funckji (sin, cos, rec, saw): sin
#
# -Podaj czestotlwosc:400
#
# -Podaj czas sygnalu (w [s]):1
#
# -Podaj rodzaj transformaty (dft, brak): dft
#
# -Czy chcesz progowac sygnal (tak,nie): nie

# %% [markdown]
# ![dft1.png](attachment:9e969cca-a51e-45ae-858c-da8400f22391.png)

# %% [markdown]
# ## Przykład 2:
# -Podaj typ funckji (sin, cos, rec, saw): saw
#
# -Podaj czestotlwosc:999
#
# -Podaj czas sygnalu (w [s]):1
#
# -Podaj rodzaj transformaty (dft, brak): dft
#
# -Czy chcesz progowac sygnal (tak,nie): nie

# %% [markdown]
# ![dft2.png](attachment:7a1727cd-f8f1-44fc-8e2d-324e000638be.png)

# %% [markdown]
# # Progowanie sygnalu

# %% [markdown]
# ## Przyklad 1
# -Podaj typ funckji (sin, cos, rec, saw): sin
#
# -Podaj czestotlwosc:5
#
# -Podaj czas sygnalu (w [s]):3
#
# -Podaj rodzaj transformaty (dft, brak): brak
#
# -Czy chcesz progowac sygnal (tak,nie): tak
#
# -Podaj prog: -0.5

# %% [markdown]
# ![progowanie1.png](attachment:3ee5d3c1-0cd8-41d8-a208-f9130c50e083.png)

# %% [markdown]
# ## Przyklad 2
# -Podaj typ funckji (sin, cos, rec, saw): saw
#
# -Podaj czestotlwosc:5
#
# -Podaj czas sygnalu (w [s]):3
#
# -Podaj rodzaj transformaty (dft, brak): brak
#
# -Czy chcesz progowac sygnal (tak,nie): tak
#
# -Podaj prog: 0.9

# %% [markdown]
# ![progowanie2.png](attachment:1a59030e-7760-4d5f-84cd-f8070c563263.png)
